# %% [markdown]
# 1. Sai Sumana Adurugatla : 1002073766
# 2. MIR MUSTAFA ALI : 1002117402
# 3. Kiran Mai Akaram : 1002115618

# %%
pip install -U lida 
#LLM
# Out:
# Note: you may need to restart the kernel to use updated packages.Requirement already satisfied: lida in c:\users\suman\appdata\local\programs\python\python311\lib\site-packages (0.0.14)
# Requirement already satisfied: llmx>=0.0.21a in c:\users\suman\appdata\local\programs\python\python311\lib\site-packages (from lida) (0.0.21a0)
# Requirement already satisfied: pydantic in c:\users\suman\appdata\local\programs\python\python311\lib\site-packages (from lida) (2.6.1)
# Requirement already satisfied: uvicorn in c:\users\suman\appdata\local\programs\python\python311\lib\site-packages (from lida) (0.27.1)
# Requirement already satisfied: typer in c:\users\suman\appdata\local\programs\python\python311\lib\site-packages (from lida) (0.9.0)
# Requirement already satisfied: fastapi in c:\users\suman\appdata\local\programs\python\python311\lib\site-packages (from lida) (0.109.2)
# Requirement already satisfied: python-multipart in c:\users\suman\appdata\local\programs\python\python311\lib\site-packages (from lida) (0.0.9)
# Requirement already satisfied: scipy in c:\users\suman\appdata\local\programs\python\python311\lib\site-packages (from lida) (1.10.1)
# Requirement already satisfied: numpy in c:\users\suman\appdata\local\programs\python\python311\lib\site-packages (from lida) (1.23.5)
# Requirement already satisfied: pandas in c:\users\suman\appdata\local\programs\python\python311\lib\site-packages (from lida) (2.1.2)
# Requirement already satisfied: matplotlib in c:\users\suman\appdata\local\programs\python\python311\lib\site-packages (from lida) (3.6.3)
# Requirement already satisfied: altair in c:\users\suman\appdata\local\programs\python\python311\lib\site-packages (from lida) (5.2.0)
# Requirement already satisfied: seaborn in c:\users\suman\appdata\local\programs\python\python311\lib\site-packages (from lida) (0.13.2)
# Requirement already satisfied: plotly in c:\users\suman\appdata\local\programs\python\python311\lib\site-packages (from lida) (5.18.0)
# Requirement already satisfied: plotnine in c:\users\suman\appdata\local\programs\python\python311\lib\site-packages (from lida) (0.12.4)
# Requirement already satisfied: statsmodels in c:\users\suman\appdata\local\programs\python\python311\lib\site-packages (from lida) (0.14.1)
# Requirement already satisfied: networkx in c:\users\suman\appdata\local\programs\python\python311\lib\site-packages (from lida) (3.2.1)
# Requirement already satisfied: geopandas in c:\users\suman\appdata\local\programs\python\python311\lib\site-packages (from lida) (0.14.3)
# Requirement already satisfied: matplotlib-venn in c:\users\suman\appdata\local\programs\python\python311\lib\site-packages (from lida) (0.11.10)
# Requirement already satisfied: wordcloud in c:\users\suman\appdata\local\programs\python\python311\lib\site-packages (from lida) (1.9.3)
# Requirement already satisfied: kaleido!=0.2.1.post1,>=0.2.1 in c:\users\suman\appdata\local\programs\python\python311\lib\site-packages (from lida) (0.2.1)
# Requirement already satisfied: openai in c:\users\suman\appdata\local\programs\python\python311\lib\site-packages (from llmx>=0.0.21a->lida) (1.12.0)
# Requirement already satisfied: tiktoken in c:\users\suman\appdata\local\programs\python\python311\lib\site-packages (from llmx>=0.0.21a->lida) (0.6.0)
# Requirement already satisfied: diskcache in c:\users\suman\appdata\local\programs\python\python311\lib\site-packages (from llmx>=0.0.21a->lida) (5.6.3)
# Requirement already satisfied: cohere in c:\users\suman\appdata\local\programs\python\python311\lib\site-packages (from llmx>=0.0.21a->lida) (4.47)
# Requirement already satisfied: google.auth in c:\users\suman\appdata\local\programs\python\python311\lib\site-packages (from llmx>=0.0.21a->lida) (2.16.2)
# Requirement already satisfied: pyyaml in c:\users\suman\appdata\local\programs\python\python311\lib\site-packages (from llmx>=0.0.21a->lida) (6.0.1)
# Requirement already satisfied: jinja2 in c:\users\suman\appdata\local\programs\python\python311\lib\site-packages (from altair->lida) (3.1.3)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\suman\appdata\local\programs\python\python311\lib\site-packages (from altair->lida) (4.21.1)
# Requirement already satisfied: packaging in c:\users\suman\appdata\local\programs\python\python311\lib\site-packages (from altair->lida) (23.0)
# Requirement already satisfied: toolz in c:\users\suman\appdata\local\programs\python\python311\lib\site-packages (from altair->lida) (0.12.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\suman\appdata\local\programs\python\python311\lib\site-packages (from pandas->lida) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\suman\appdata\local\programs\python\python311\lib\site-packages (from pandas->lida) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\suman\appdata\local\programs\python\python311\lib\site-packages (from pandas->lida) (2023.3)
# Requirement already satisfied: starlette<0.37.0,>=0.36.3 in c:\users\suman\appdata\local\programs\python\python311\lib\site-packages (from fastapi->lida) (0.36.3)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\suman\appdata\local\programs\python\python311\lib\site-packages (from fastapi->lida) (4.9.0)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\suman\appdata\local\programs\python\python311\lib\site-packages (from pydantic->lida) (0.6.0)
# Requirement already satisfied: pydantic-core==2.16.2 in c:\users\suman\appdata\local\programs\python\python311\lib\site-packages (from pydantic->lida) (2.16.2)
# Requirement already satisfied: fiona>=1.8.21 in c:\users\suman\appdata\local\programs\python\python311\lib\site-packages (from geopandas->lida) (1.9.5)
# Requirement already satisfied: pyproj>=3.3.0 in c:\users\suman\appdata\local\programs\python\python311\lib\site-packages (from geopandas->lida) (3.6.1)
# Requirement already satisfied: shapely>=1.8.0 in c:\users\suman\appdata\local\programs\python\python311\lib\site-packages (from geopandas->lida) (2.0.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\suman\appdata\local\programs\python\python311\lib\site-packages (from matplotlib->lida) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in c:\users\suman\appdata\local\programs\python\python311\lib\site-packages (from matplotlib->lida) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\suman\appdata\local\programs\python\python311\lib\site-packages (from matplotlib->lida) (4.38.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\suman\appdata\local\programs\python\python311\lib\site-packages (from matplotlib->lida) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\suman\appdata\local\programs\python\python311\lib\site-packages (from matplotlib->lida) (9.4.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\suman\appdata\local\programs\python\python311\lib\site-packages (from matplotlib->lida) (3.0.9)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\suman\appdata\local\programs\python\python311\lib\site-packages (from plotly->lida) (8.2.3)
# Requirement already satisfied: mizani<0.10.0,>0.9.0 in c:\users\suman\appdata\local\programs\python\python311\lib\site-packages (from plotnine->lida) (0.9.3)
# Requirement already satisfied: patsy>=0.5.1 in c:\users\suman\appdata\local\programs\python\python311\lib\site-packages (from plotnine->lida) (0.5.6)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\suman\appdata\local\programs\python\python311\lib\site-packages (from typer->lida) (8.1.7)
# Requirement already satisfied: h11>=0.8 in c:\users\suman\appdata\local\programs\python\python311\lib\site-packages (from uvicorn->lida) (0.14.0)
# Requirement already satisfied: colorama in c:\users\suman\appdata\local\programs\python\python311\lib\site-packages (from click<9.0.0,>=7.1.1->typer->lida) (0.4.6)
# Requirement already satisfied: attrs>=19.2.0 in c:\users\suman\appdata\local\programs\python\python311\lib\site-packages (from fiona>=1.8.21->geopandas->lida) (22.2.0)
# Requirement already satisfied: certifi in c:\users\suman\appdata\local\programs\python\python311\lib\site-packages (from fiona>=1.8.21->geopandas->lida) (2022.12.7)
# Requirement already satisfied: click-plugins>=1.0 in c:\users\suman\appdata\local\programs\python\python311\lib\site-packages (from fiona>=1.8.21->geopandas->lida) (1.1.1)
# Requirement already satisfied: cligj>=0.5 in c:\users\suman\appdata\local\programs\python\python311\lib\site-packages (from fiona>=1.8.21->geopandas->lida) (0.7.2)
# Requirement already satisfied: six in c:\users\suman\appdata\local\programs\python\python311\lib\site-packages (from fiona>=1.8.21->geopandas->lida) (1.16.0)
# Requirement already satisfied: setuptools in c:\users\suman\appdata\local\programs\python\python311\lib\site-packages (from fiona>=1.8.21->geopandas->lida) (65.5.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\suman\appdata\local\programs\python\python311\lib\site-packages (from jsonschema>=3.0->altair->lida) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\suman\appdata\local\programs\python\python311\lib\site-packages (from jsonschema>=3.0->altair->lida) (0.33.0)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\suman\appdata\local\programs\python\python311\lib\site-packages (from jsonschema>=3.0->altair->lida) (0.17.1)
# Requirement already satisfied: anyio<5,>=3.4.0 in c:\users\suman\appdata\local\programs\python\python311\lib\site-packages (from starlette<0.37.0,>=0.36.3->fastapi->lida) (4.2.0)
# Requirement already satisfied: aiohttp<4.0,>=3.0 in c:\users\suman\appdata\local\programs\python\python311\lib\site-packages (from cohere->llmx>=0.0.21a->lida) (3.9.3)
# Requirement already satisfied: backoff<3.0,>=2.0 in c:\users\suman\appdata\local\programs\python\python311\lib\site-packages (from cohere->llmx>=0.0.21a->lida) (2.2.1)
# Requirement already satisfied: fastavro<2.0,>=1.8 in c:\users\suman\appdata\local\programs\python\python311\lib\site-packages (from cohere->llmx>=0.0.21a->lida) (1.9.3)
# Requirement already satisfied: importlib_metadata<7.0,>=6.0 in c:\users\suman\appdata\local\programs\python\python311\lib\site-packages (from cohere->llmx>=0.0.21a->lida) (6.11.0)
# Requirement already satisfied: requests<3.0.0,>=2.25.0 in c:\users\suman\appdata\local\programs\python\python311\lib\site-packages (from cohere->llmx>=0.0.21a->lida) (2.28.2)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\users\suman\appdata\local\programs\python\python311\lib\site-packages (from cohere->llmx>=0.0.21a->lida) (1.26.15)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\suman\appdata\local\programs\python\python311\lib\site-packages (from google.auth->llmx>=0.0.21a->lida) (5.3.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\suman\appdata\local\programs\python\python311\lib\site-packages (from google.auth->llmx>=0.0.21a->lida) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\suman\appdata\local\programs\python\python311\lib\site-packages (from google.auth->llmx>=0.0.21a->lida) (4.9)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\suman\appdata\local\programs\python\python311\lib\site-packages (from jinja2->altair->lida) (2.1.2)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\suman\appdata\local\programs\python\python311\lib\site-packages (from openai->llmx>=0.0.21a->lida) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\suman\appdata\local\programs\python\python311\lib\site-packages (from openai->llmx>=0.0.21a->lida) (0.26.0)
# Requirement already satisfied: sniffio in c:\users\suman\appdata\local\programs\python\python311\lib\site-packages (from openai->llmx>=0.0.21a->lida) (1.3.0)
# Requirement already satisfied: tqdm>4 in c:\users\suman\appdata\local\programs\python\python311\lib\site-packages (from openai->llmx>=0.0.21a->lida) (4.66.2)
# Requirement already satisfied: regex>=2022.1.18 in c:\users\suman\appdata\local\programs\python\python311\lib\site-packages (from tiktoken->llmx>=0.0.21a->lida) (2023.12.25)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\suman\appdata\local\programs\python\python311\lib\site-packages (from aiohttp<4.0,>=3.0->cohere->llmx>=0.0.21a->lida) (1.3.1)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\suman\appdata\local\programs\python\python311\lib\site-packages (from aiohttp<4.0,>=3.0->cohere->llmx>=0.0.21a->lida) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\suman\appdata\local\programs\python\python311\lib\site-packages (from aiohttp<4.0,>=3.0->cohere->llmx>=0.0.21a->lida) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\suman\appdata\local\programs\python\python311\lib\site-packages (from aiohttp<4.0,>=3.0->cohere->llmx>=0.0.21a->lida) (1.9.4)
# Requirement already satisfied: idna>=2.8 in c:\users\suman\appdata\local\programs\python\python311\lib\site-packages (from anyio<5,>=3.4.0->starlette<0.37.0,>=0.36.3->fastapi->lida) (3.4)
# Requirement already satisfied: httpcore==1.* in c:\users\suman\appdata\local\programs\python\python311\lib\site-packages (from httpx<1,>=0.23.0->openai->llmx>=0.0.21a->lida) (1.0.2)
# Requirement already satisfied: zipp>=0.5 in c:\users\suman\appdata\local\programs\python\python311\lib\site-packages (from importlib_metadata<7.0,>=6.0->cohere->llmx>=0.0.21a->lida) (3.17.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\suman\appdata\local\programs\python\python311\lib\site-packages (from pyasn1-modules>=0.2.1->google.auth->llmx>=0.0.21a->lida) (0.4.8)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\suman\appdata\local\programs\python\python311\lib\site-packages (from requests<3.0.0,>=2.25.0->cohere->llmx>=0.0.21a->lida) (3.1.0)
# [notice] A new release of pip is available: 23.3.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ## Using lida to use LLM
#
# ## Task 3: LLM
# 1. For this task you will be using the "CarPrice.csv" data file.
# 2. Load the data  and perform the analysis asked for each question.
# 3. Load and Display the clear screenshot for each question analysis respectively.
#
# Note: Target variable is 'price'

# %%
from lida import Manager, TextGenerationConfig , llm

# %%
lida = Manager(text_gen = llm("openai", api_key="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")) # !! api key
textgen_config = TextGenerationConfig(n=1, temperature=0.5, model="gpt-3.5-turbo-0301", use_cache=True)

summary = lida.summarize("C:\\Users\\suman\\Documents\\Data Mining\\SPRING2024_Section3\\SPRING2024_Section3\\CarPrice.csv", summary_method="default", textgen_config=textgen_config)  
goals = lida.goals(summary, n=2, textgen_config=textgen_config)

for goal in goals:
    display(goal)
# Out:
# c:\Users\suman\AppData\Local\Programs\Python\Python311\Lib\site-packages\lida\components\summarizer.py:61: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   elif pd.api.types.is_categorical_dtype(df[column]):
# c:\Users\suman\AppData\Local\Programs\Python\Python311\Lib\site-packages\lida\components\summarizer.py:61: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   elif pd.api.types.is_categorical_dtype(df[column]):
# c:\Users\suman\AppData\Local\Programs\Python\Python311\Lib\site-packages\lida\components\summarizer.py:61: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   elif pd.api.types.is_categorical_dtype(df[column]):
# c:\Users\suman\AppData\Local\Programs\Python\Python311\Lib\site-packages\lida\components\summarizer.py:61: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   elif pd.api.types.is_categorical_dtype(df[column]):
# Goal(question='What is the relationship between car price and engine size?', visualization='scatter plot of engine size vs price', rationale='This visualization will show if there is a correlation between the engine size and the price of the car. This can help us understand if cars with larger engines are more expensive than those with smaller engines.', index=0)
# Goal(question='What is the most common carbody type among the dataset?', visualization='bar chart of carbody type counts', rationale='This visualization will give us insight into the most common carbody type among the dataset, which can help us understand the preferences of car buyers. Additionally, this can help manufacturers understand which carbody types are in high demand and should be produced more.', index=1)

# %%
# targe variable as price 
persona = "a mechanic who wants to buy a car that has low price"
personal_goals = lida.goals(summary, n=2, persona=persona, textgen_config=textgen_config)
for goal in personal_goals:
    display(goal)
# Out:
# Goal(question='What is the relationship between engine size and price for cars with diesel fuel type?', visualization='scatter plot of engine size vs price for cars with diesel fuel type', rationale='This visualization will help the mechanic to understand the relationship between engine size and price for cars with diesel fuel type. The mechanic can use this information to identify cars with a larger engine size that may be available at a lower price point.', index=0)
# Goal(question='What is the distribution of curb weight for cars with different car body types?', visualization='box plot of curb weight for each car body type', rationale="This visualization will help the mechanic to understand the distribution of curb weight for each car body type. The mechanic can use this information to identify car body types that tend to have a higher or lower curb weight, which may impact the car's performance and fuel efficiency.", index=1)

# %%
i = 0
library = "seaborn"
textgen_config = TextGenerationConfig(n=1, temperature=0.2, use_cache=True)
charts = lida.visualize(summary=summary, goal=goals[i], textgen_config=textgen_config, library=library)  
charts[0]
# Out:
# import seaborn as sns
# import pandas as pd
# import matplotlib.pyplot as plt
#
# def plot(data: pd.DataFrame):
#     # solution plan
#     # i. Select the columns 'price' and 'enginesize' from the data
#     # ii. Plot a scatter plot of 'price' vs 'enginesize'
#     # iii. Set the x and y axis labels
#     # iv. Set the title of the plot
#     # v. Return the plot object
#
#     plt.figure(figsize=(10,6))
#     sns.scatterplot(x='enginesize', y='price', data=data)
#     plt.xlabel('Engine Size')
#     plt.ylabel('Price')
#     plt.title('What is the relationship between car price and engine size?', wrap=True)
#     return plt;
#
# chart = plot(data)

# %% [markdown]
# ### Task 3A:
# Display visualization for each column

# %%
user_query = "display visualization for each column "
textgen_config = TextGenerationConfig(n=1, temperature=0.2, use_cache=True)
charts = lida.visualize(summary=summary, goal=user_query, textgen_config=textgen_config)  
charts[0]
# Out:
# import seaborn as sns
# import pandas as pd
# import matplotlib.pyplot as plt
#
# def plot(data: pd.DataFrame):
#     # solution plan
#     # i.  ..
#     for column in data.columns:
#         if data[column].dtype == 'object':
#             sns.countplot(x=column, data=data)
#         else:
#             sns.histplot(x=column, data=data)
#         plt.title(column, wrap=True)
#         plt.show()
#     return plt
#
# chart = plot(data)

# %% [markdown]
# ### Task 3B:
# Display car length vs highway mpg with reaction to target variable.
# Interpret the graph.

# %%
#Display car length vs highway mpg with reaction to target variable.
user_query = "Display car length vs highway mpg with reaction to price variable "
textgen_config = TextGenerationConfig(n=1, temperature=0.2, use_cache=True)
charts = lida.visualize(summary=summary, goal=user_query, textgen_config=textgen_config)  
charts[0]
# Out:
# import seaborn as sns
# import pandas as pd
# import matplotlib.pyplot as plt
#
# # solution plan
# # i. Select the required columns from the data
# # ii. Create a scatter plot with car length on x-axis, highway mpg on y-axis and price as hue
#
# def plot(data: pd.DataFrame):
#     required_cols = ['carlength', 'highwaympg', 'price']
#     plot_data = data[required_cols]
#     plt.figure(figsize=(10, 8))
#     sns.scatterplot(x='carlength', y='highwaympg', hue='price', data=plot_data, palette='coolwarm')
#     plt.title('Display car length vs highway mpg with reaction to price variable ', wrap=True)
#     return plt;
#
# chart = plot(data)

# %% [markdown]
# There does not appear to be a strong linear relationship between the two variables.
# - Longer cars do not necessarily have higher highway mpg price.
# - There is a weak tendency for cars with longer car lengths to also have higher highway mpg price.
# - Few cars that do not follow this trend.
# -  there is a lot of variability in the data.
# - The longer the car length has the  higher the price.
# - the higher highway MPG has the lower price cars.
# - The luxury cars tend to be lengthier since they are loaded with features which results in lesser highway MPG
# - the cheaper cars have varying car length but are mostly with higher highway MPG making them very efficient for long traveller and budget friendly.

# %% [markdown]
# ### Task 3C: 3 points
#
# Display peak rpm vs horsepower with reaction to target variable. Interpret your graph.

# %%
#Display peak rpm vs horsepower with reaction to target variable. Interpret your graph.
user_query = "Display peak rpm vs horsepower with reaction to target price variable "
textgen_config = TextGenerationConfig(n=1, temperature=0.2, use_cache=True)
charts = lida.visualize(summary=summary, goal=user_query, textgen_config=textgen_config)  
charts[0]
# Out:
# import seaborn as sns
# import pandas as pd
# import matplotlib.pyplot as plt
#
# def plot(data: pd.DataFrame):
#     # solution plan
#     # i. Select the columns 'horsepower', 'peakrpm', and 'price' from the data
#     # ii. Create a scatter plot of 'horsepower' vs 'peakrpm' with hue set to 'price'
#     # iii. Set the title of the plot and return the plot object
#
#     # i. Select the columns 'horsepower', 'peakrpm', and 'price' from the data
#     df = data[['horsepower', 'peakrpm', 'price']]
#
#     # ii. Create a scatter plot of 'horsepower' vs 'peakrpm' with hue set to 'price'
#     chart = sns.scatterplot(data=df, x='horsepower', y='peakrpm', hue='price', palette='coolwarm')
#
#     # iii. Set the title of the plot and return the plot object
#     plt.title('Display peak rpm vs horsepower with reaction to target price variable. Interpret your graph. ', wrap=True)
#     return plt;
#
# chart = plot(data)

# %% [markdown]
# # Comment your interpretations here
# """
# - There does not appear to be a strong linear relationship between the two variables.
# -  There is a weak tendency for cars with higher peak rpm to also have higher horsepower.
# - Few cars that do not follow this trend.
# -  there is a lot of variability in the data.
# - The higher the peak rpm has the higher the price.
# - The lower the peak rpm has the lower the price.
# - The higher the peak rpm has the higher the horsepower.
# - The cheap cars have varying peak rpm but are mostly under 150 HorsePower. it might due to targetting different customer segments with different needs.
# - The medium segments have more horsepower and higher rpm compared other price segments must be due to enthusiastas and performance oriented customers.
# """

# %% [markdown]
# ### Task 3D: 3 points
#
# Display horsepower vs cylindernumber in reaction to the target variable. Interpret your graph.

# %%
#Display horsepower vs cylindernumber in reaction to the target variable. Interpret your graph.

user_query = " Display horsepower vs cylindernumber in reaction to the target variable "
textgen_config = TextGenerationConfig(n=1, temperature=0.2, use_cache=True)
charts = lida.visualize(summary=summary, goal=user_query, textgen_config=textgen_config)  
charts[0]
# Out:
# import seaborn as sns
# import pandas as pd
# import matplotlib.pyplot as plt
#
# def plot(data: pd.DataFrame):
#     # solution plan
#     # i.  ..
#     sns.scatterplot(data=data, x='cylindernumber', y='horsepower', hue='price')
#     plt.title('Display horsepower vs cylindernumber in reaction to the target variable', wrap=True)
#     return plt;
#
# chart = plot(data)

# %% [markdown]
# # Comment your interpretations
#
# """
# - cheap cars have four cylinder number. and very less horsepower
# - 10000 price cars have 4 cylinder number and 0-100 horsepower
# - expensive tend towards 6 and 8 cylinder number and 100-200 horsepower
# - medium price cars are more over 4, 6.
# - the cheaper cars since they have  less power, 4 cylinders is optimal for the price and efficiency since the customer segment is looking for a car that is affordable and efficient.
# """

# %% [markdown]
# ### Task 3E: 3 points
#
# Display engine size vs fuel system in reaction to the target variable. Interpret your graph.

# %%
# Display engine size vs fuel system in reaction to the target variable. Interpret your graph.
user_query = " Display engine size vs fuel system y axis in reaction to target price"
textgen_config = TextGenerationConfig(n=1, temperature=0.2, use_cache=True)
charts = lida.visualize(summary=summary, goal=user_query, textgen_config=textgen_config)  
charts[0]
# Out:
# import seaborn as sns
# import pandas as pd
# import matplotlib.pyplot as plt
#
# def plot(data: pd.DataFrame):
#     # solution plan
#     # i.  Display engine size vs fuel system y axis in reaction to target price
#     sns.scatterplot(x='enginesize', y='fuelsystem', hue='price', data=data)
#     plt.title('Display engine size vs fuel system y axis in reaction to target price', wrap=True)
#     return plt;
#
# chart = plot(data)

# %% [markdown]
# # Comment your interpretations
#
# """
# - cheap cars have 120-150 engine size and varying fuel system.
# - expsenive cars have 200 - 300 engine size and mpfi fuel system.
# - medium price cars are more over 120-200 engine size and mpfi-idi fuel system.
# - this interprets that more engine size give more price and predominatly mpfi fuel system.
# - The cheapers cars have less engine size and varying fuel system.
# - The medium price cars are majorly into idi/ mpfi fuel system and 120-200 engine size.
#
# """

# %% [markdown]
# ### Task 3F: 5 points
#
# Display curbweight vs citympg in reaction to the target variable. Interpret your graph.

# %%
# Display curbweight vs citympg in reaction to the target variable. Interpret your graph.
user_query = " # Display curbweight vs citympg in reaction to the target variable "
textgen_config = TextGenerationConfig(n=1, temperature=0.2, use_cache=True)
charts = lida.visualize(summary=summary, goal=user_query, textgen_config=textgen_config)  
charts[0]
# Out:
# import seaborn as sns
# import pandas as pd
# import matplotlib.pyplot as plt
#
# def plot(data: pd.DataFrame):
#     # solution plan
#     # i. Display curbweight vs citympg in reaction to the target variable
#     sns.scatterplot(x='curbweight', y='citympg', hue='price', data=data, palette='coolwarm')
#     plt.axvline(data['curbweight'].median(), color='black', linestyle='--', label='Median curbweight: {:.2f}'.format(data['curbweight'].median()))
#     plt.legend()
#     plt.title('Display curbweight vs citympg in reaction to the target variable', wrap=True)
#     plt.xlabel('Curbweight')
#     plt.ylabel('City MPG')
#     return plt;
#
# chart = plot(data)

# %% [markdown]
# """
# - expensive cars have 3000-4000 curb weight and 10-30 city mpg.
# - cheap cars have 1500-3000 curb weight and 20-40 city mpg.
# - this interprets that more curb price give less mileage and becomes more expensive.
# - allowing less curb weight gives more mileage and becomes less expensive.
# """
